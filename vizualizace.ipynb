# %% [markdown]
# # Vizualizace množin

# %% [markdown]
# Importování potřebných knihoven:

# %%
#načtení knihovny
import mandelbrot as mb

# %% [markdown]
# ## Mandelbrotova množina

# %%
#vykreslení mandlebrotovy množiny s různými středy a zoomem 
mb.vizualizace.mandelbrot_visual()
mb.vizualizace.mandelbrot_visual(center=0.0+ 1.0j, side_length=1e-4)
